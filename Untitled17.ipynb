# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("INX_Future_Inc_Employee_Performance_Data.csv")

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.corr() >0.5
# Out:
#                              Age  DistanceFromHome  Education  EmployeeCount  \
# Age                         True             False      False          False
# DistanceFromHome           False              True      False          False
# Education                  False             False       True          False
# EmployeeCount              False             False      False          False
# EnvironmentSatisfaction    False             False      False          False
# HourlyRate                 False             False      False          False
# JobInvolvement             False             False      False          False
# JobLevel                    True             False      False          False
# JobSatisfaction            False             False      False          False
# NumCompaniesWorked         False             False      False          False
# PercentSalaryHike          False             False      False          False
# ...

# %%
data.iloc[:,1:10]
# Out:
#       Age  Gender    EducationField MaritalStatus              Department  \
# 0      41  Female     Life Sciences        Single                   Sales
# 1      49    Male     Life Sciences       Married             Development
# 2      37    Male             Other        Single             Development
# 3      33  Female     Life Sciences       Married             Development
# 4      27    Male           Medical       Married             Development
# 5      32    Male     Life Sciences        Single             Development
# 6      59  Female           Medical       Married             Development
# 7      30    Male     Life Sciences      Divorced             Development
# 8      38    Male     Life Sciences        Single             Development
# 9      36    Male           Medical       Married             Development
# 10     35    Male           Medical       Married             Development
# 11     29  Female     Life Sciences        Single             Development
# ...

# %%
data.iloc[:,10:20]
# Out:
#       EmployeeCount  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                 1                        2          94               3
# 1                 1                        3          61               2
# 2                 1                        4          92               2
# 3                 1                        4          56               3
# 4                 1                        1          40               3
# 5                 1                        4          79               3
# 6                 1                        3          81               4
# 7                 1                        4          67               3
# 8                 1                        4          44               2
# 9                 1                        3          94               3
# 10                1                        1          84               4
# 11                1                        4          49               2
# ...
